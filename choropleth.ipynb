# %%
import pandas as pd
import folium

# %%
df_demo = pd.read_csv('data/ibaraki.csv',encoding='cp932')

# %%
df = df_demo.loc[16:,['県・地域・市町村','人口（平成29年10月1日現在）_総数','面積_人口密度〔人/k㎡〕']]
df.columns = ['city','population','density']

# %%
df = df.drop([48,52,54,56,60,62,65])
df
# Out:
#        city population   density
# 16      水戸市    270,775  1,246.00
# 17      日立市    180,781     800.7
# 18      土浦市    139,653  1,136.40
# 19      古河市    140,556  1,137.40
# 20      石岡市     74,666     346.4
# 21      結城市     51,476     782.8
# 22     龍ケ崎市     77,433     985.8
# 23      下妻市     42,705       528
# 24      常総市     60,829       492
# 25    常陸太田市     50,728     136.4
# 26      高萩市     28,768     148.6
# 27     北茨城市     43,135     230.9
# 28      笠間市     75,698     314.9
# 29      取手市    105,447  1,507.70
# 30      牛久市     84,820  1,439.60
# 31     つくば市    233,549     823.2
# 32   ひたちなか市    155,970  1,560.30
# 33      鹿嶋市     67,802     639.5
# 34      潮来市     28,491       399
# 35      守谷市     66,230  1,854.70
# 36    常陸大宮市     41,342     118.6
# 37      那珂市     53,897       551
# 38      筑西市    102,818     500.8
# 39      坂東市     53,242     432.8
# 40      稲敷市     41,392     201.1
# 41  かすみがうら市     41,297     263.7
# 42      桜川市     41,278     229.2
# ...
